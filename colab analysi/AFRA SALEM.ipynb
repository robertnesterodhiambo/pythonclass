# %% [markdown]
# ### **Statistical Intuitions and Applications**
#
# # **Assignment #1**

# %% [markdown]
# # module  importation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import scipy.stats as stats

# %% [markdown]
# # TASK 1

# %%
try:
    df = pd.read_csv('AFRA SALEM.csv')        
except FileNotFoundError:
    original_data = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/main/Data%20Sets/body_measurement.csv")
    df1 = original_data.sample(100)
    df1.to_csv('AFRA SALEM.csv')                   
    df = pd.read_csv('AFRA SALEM.csv')             
    df = pd.DataFrame(df)
    df.to_csv('AFRA SALEM.csv')                    

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  bia_di  bii_di  bit_di  che_de  che_di  elb_di  \
# 0           488         184    43.2    31.3    34.0    23.0    32.6    15.7
# 1             4         349    35.2    25.1    33.0    20.0    26.6    11.6
# 2           227         260    39.5    30.0    31.7    17.3    27.3    12.8
# 3             2         494    35.3    25.4    28.5    15.1    24.9    10.6
# 4           287         138    39.4    29.7    33.1    23.0    30.4    14.2
#
#    wri_di  kne_di  ...  bic_gi  for_gi  kne_gi  cal_gi  ank_gi  wri_gi  age  \
# 0    11.5    20.5  ...    36.8    29.0    36.9    38.9    24.2    17.9   44
# 1     9.1    21.0  ...    33.8    24.6    38.2    39.8    22.0    14.4   31
# 2     9.2    18.1  ...    25.9    22.9    36.1    35.3    20.9    14.4   25
# 3    10.4    17.0  ...    26.8    22.8    34.4    33.1    21.0    15.4   31
# 4    11.6    20.4  ...    36.6    28.4    38.2    36.6    22.9    18.1   45
#
#     wgt    hgt  sex
# 0  90.5  188.0    1
# 1  73.2  151.1    0
# 2  62.5  172.9    0
# 3  46.8  149.9    0
# 4  84.5  167.6    1
#
# [5 rows x 27 columns]
