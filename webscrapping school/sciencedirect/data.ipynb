# %%
import pandas as pd

# Load the Excel file into a DataFrame
file_path = 'ScienceDirect  Second LAST.xlsx'

df = pd.read_excel(file_path)
df
# Out:
#       Sr. No.  Sr. No..1                   PII  \
# 0           1          1     S129325580000128X
# 1           2          2     S0921509304007427
# 2           3          3     B0123693950008654
# 3           4          4     S0257897206004117
# 4           5          5     S0007850607001540
# ...       ...        ...                   ...
# 4383     4384       4384     S221486042400037X
# 4384     4385       4385  B9780443159176000013
# 4385     4386       4386  B9780443159176000141
# 4386     4387       4387  B9780443154256000043
# 4387     4388       4388  B9780443154256000195
#
#                                                    Link  Sr. No..2  \
# 0     https://www.sciencedirect.com//science/article...          1
# 1     https://www.sciencedirect.com//science/article...          2
# 2     https://www.sciencedirect.com//science/article...          3
# 3     https://www.sciencedirect.com//science/article...          4
# 4     https://www.sciencedirect.com//science/article...          5
# ...                                                 ...        ...
# 4383  https://www.sciencedirect.com//science/article...       4384
# 4384  https://www.sciencedirect.com//science/article...       4385
# 4385  https://www.sciencedirect.com//science/article...       4386
# 4386  https://www.sciencedirect.com//science/article...       4387
# 4387  https://www.sciencedirect.com//science/article...       4388
#
#                                                   Title  \
# 0     The influence of different additives and the m...
# 1     Direct laser sintering of iron–graphite powder...
# 2                          OPTICAL MATERIALS | Plastics
# 3     Characterization of the process control for th...
# 4     Consolidation phenomena in laser and powder-be...
# ...                                                 ...
# 4383  3D printed elastic fluoropolymer with high str...
# 4384  1: Recent trends in “conventional” manufacturi...
# 4385                               List of contributors
# 4386  10: Artificial intelligence (AI) enhanced fini...
# 4387                               List of contributors
#
#                                                Abstract Publication_date
# 0     The influence of different additives (TiO 2, T...       2000-01-01
# 1     In the present work, the role of graphite addi...       2004-10-15
# 2     njection molded precision plastic optics in hi...       2005-01-01
# 3     Direct Laser Metallic Powder Deposition Proces...       2006-12-04
# 4     Layered manufacturing (LM) is gaining ground f...       2007-01-01
# ...                                                 ...              ...
# 4383  Elastomeric materials, most prominently polydi...       2024-02-05
# 4384  Composite structures, based on the combination...       2024-01-01
# 4385                                                  -       2024-01-01
# 4386  The local geometrical randomness of metal foam...       2024-01-01
# 4387                                                  -       2024-01-01
#
# [4388 rows x 8 columns]

# %%
import pandas as pd

# Load the Excel file and specify the sheet name
file_path = 'ScienceDirect  Second LAST.xlsx'
df = pd.read_excel(file_path, sheet_name='Authors Info')

# Strip any whitespace from the column names (optional but recommended)
df.columns = df.columns.str.strip()

# Now you can filter based on the 'Author' column
blank_author_df = df[df['Author'].isna()]

# Continue with the rest of your code...

# %%
import pandas as pd

# Load the Excel file and specify the sheet name
file_path = 'ScienceDirect  Second LAST.xlsx'
df = pd.read_excel(file_path, sheet_name='Authors Info')

# Strip any whitespace from the column names (optional but recommended)
df.columns = df.columns.str.strip()

# Now you can filter based on the 'Author' column
blank_author_df = df[df['Author'].isna()]




# Filter the DataFrame where the "Author" column is not blank
non_blank_author_df = df.dropna(subset=['Author'])

# Group the non-blank DataFrame by 'Link', 'Author', and 'Affiliation'
grouped_df = non_blank_author_df.groupby(['Link', 'Author', 'Affiliation']).size().reset_index(name='count')

# Identify groups where the count is 1
unique_groups = grouped_df[grouped_df['count'] == 1]

# Merge these unique groups back with the blank_author_df based on the 'Link'
merged_df = pd.merge(blank_author_df, unique_groups[['Link', 'Author', 'Affiliation']], on='Link', how='left')

# Update the blank_author_df with the found 'Author' and 'Affiliation'
blank_author_df.update(merged_df)

# Replace the updated blank rows in the original DataFrame
df.update(blank_author_df)

# Save the updated DataFrame back to an Excel file
output_file_path = 'Updated_ScienceDirect.xlsx'
df.to_excel(output_file_path, index=False)

print("The DataFrame has been updated and saved as 'Updated_ScienceDirect.xlsx'")
# Out:
# The DataFrame has been updated and saved as 'Updated_ScienceDirect.xlsx'

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import PatternFill

# Load the Excel file with openpyxl
file_path = 'ScienceDirect  Second LAST.xlsx'
wb = load_workbook(file_path)
ws = wb['Authors Info']

# Load the sheet data into a DataFrame using pandas
df = pd.read_excel(file_path, sheet_name='Authors Info')

# Strip any whitespace from the column names
df.columns = df.columns.str.strip()

# Store the 'Link' column values to identify altered rows
original_links = set(df['Link'])

# Process the DataFrame
# Filter the DataFrame where the "Author" column is blank
blank_author_df = df[df['Author'].isna()]

# Filter the DataFrame where the "Author" column is not blank
non_blank_author_df = df.dropna(subset=['Author'])

# Group the non-blank DataFrame by 'Link', 'Author', and 'Affiliation'
grouped_df = non_blank_author_df.groupby(['Link', 'Author', 'Affiliation']).size().reset_index(name='count')

# Identify groups where the count is 1
unique_groups = grouped_df[grouped_df['count'] == 1]

# Merge these unique groups back with the blank_author_df based on the 'Link'
merged_df = pd.merge(blank_author_df, unique_groups[['Link', 'Author', 'Affiliation']], on='Link', how='left')

# Update the blank_author_df with the found 'Author' and 'Affiliation'
blank_author_df.update(merged_df)

# Replace the updated blank rows in the original DataFrame
df.update(blank_author_df)

# Save the updated DataFrame back to the Excel file with the correct sheet name
output_file_path = 'Updated_ScienceDirect.xlsx'
with pd.ExcelWriter(output_file_path, engine='openpyxl') as writer:
    df.to_excel(writer, sheet_name='Authors Info', index=False)

# Load the updated workbook to change the cell colors
updated_wb = load_workbook(output_file_path)
updated_ws = updated_wb['Authors Info']

# Define a blue fill for altered cells
blue_fill = PatternFill(start_color='0000FF', end_color='0000FF', fill_type='solid')

# Set the color to blue for the altered 'Link' cells
for row in updated_ws.iter_rows(min_col=2, max_col=2, min_row=2):  # Adjust min_row if necessary
    cell = row[0]
    if cell.value in blank_author_df['Link'].values:
        cell.fill = blue_fill

# Save the file with updated colors
updated_wb.save(output_file_path)

print("The DataFrame has been updated and saved as 'Updated_ScienceDirect.xlsx' with altered links colored blue.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 7
#       5 # Load the Excel file with openpyxl
#       6 file_path = 'ScienceDirect Second LAST.xlsx'
# ----> 7 wb = load_workbook(file_path)
#       8 ws = wb['Authors Info']
#      10 # Load the sheet data into a DataFrame using pandas
#
# File ~/.local/lib/python3.12/site-packages/openpyxl/reader/excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     317                   data_only=False, keep_links=True, rich_text=False):
#     318     """Open the given filename and return the workbook
#     319
#     320     :param filename: the path to open or a file-like object
#    (...)
#     344
#     345     """
# --> 346     reader = ExcelReader(filename, read_only, keep_vba,
#     347                          data_only, keep_links, rich_text)
#     348     reader.read()
#     349     return reader.wb
#
# File ~/.local/lib/python3.12/site-packages/openpyxl/reader/excel.py:123, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
#     121 def __init__(self, fn, read_only=False, keep_vba=KEEP_VBA,
#     122              data_only=False, keep_links=True, rich_text=False):
# --> 123     self.archive = _validate_archive(fn)
#     124     self.valid_files = self.archive.namelist()
#     125     self.read_only = read_only
#
# File ~/.local/lib/python3.12/site-packages/openpyxl/reader/excel.py:95, in _validate_archive(filename)
#      88             msg = ('openpyxl does not support %s file format, '
#      89                    'please check you can open '
#      90                    'it with Excel first. '
#      91                    'Supported formats are: %s') % (file_format,
#      92                                                    ','.join(SUPPORTED_FORMATS))
#      93         raise InvalidFileException(msg)
# ---> 95 archive = ZipFile(filename, 'r')
#      96 return archive
#
# File /usr/local/lib/python3.12/zipfile/__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ScienceDirect Second LAST.xlsx'
